# %%
import sys
import os
sys.path.append(os.path.abspath('../'))
from dynamo.seasonal_features_analysis import ASVSeasonalityAnalysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.dpi'] = 100
sns.set_style('whitegrid')
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 1

subject_cmap = {'male':'#d36135', 
        'female':'#ffb400' ,
        'donorA':'#227c9d', 
        'donorB':'#7fb069'}

# %%
df_seasonal = pd.read_csv('./data/data_original/ts_charactericstics_tables/LONGITUDINAL_CHARACTERISTICS_DF.csv')
explained_fft_df = pd.read_csv('./data/data_original/ts_charactericstics_tables/explained_fft_df.csv')
df_seasonal = df_seasonal.rename({'seasonal_reconstruction_score': 'seasonal_reconstruction_score_6modes'}, axis=1)

# %%
analysis = ASVSeasonalityAnalysis(df_seasonal, explained_fft_df, subject_cmap)

# %%
analysis.plot_modes_vs_score()

# %%
analysis.plot_fourier_seasonalities()

# %%
analysis.plot_dominant_seasonalities_combined()

# %%
analysis.plot_histogram_seasonality()

# %%
analysis.plot_seasonal_bacteria()
# Out:
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonal_features_analysis.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modes_saturation['seasonal'] = np.where(modes_saturation['seasonal_reconstruction_score'] > 0.5, 1, 0)
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonal_features_analysis.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modes_saturation['bacteria'] = np.where(modes_saturation['n_modes'] == 6, 1, 0)

# %%
analysis.plot_seasonal_vs_flatness()

# %%
analysis.plot_white_noise_behavior()
# Out:
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonal_features_analysis.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modes_saturation['seasonal'] = np.where(modes_saturation['seasonal_reconstruction_score'] > 0.5, 1, 0)
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonal_features_analysis.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modes_saturation['bacteria'] = np.where(modes_saturation['n_modes'] == 6, 1, 0)
# ...
