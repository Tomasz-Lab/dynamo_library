# %%
import sys
import os
sys.path.append(os.path.abspath('../'))
from dynamo.seasonality_analysis import SeasonalityAnalysis
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
sns.set_style('whitegrid')
mpl.rcParams['figure.dpi'] = 100
plt.rcParams['legend.title_fontsize'] = 'large'
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 1

# %%
wd =  './data/data_original/'

# %% [markdown]
# ## I. Shannon diversity index

# %%
n=0
male_alpha_df = pd.read_csv(wd + 'alpha_diversity/shannon/male_shannon_entropy.csv').iloc[n:150]
female_alpha_df = pd.read_csv(wd + 'alpha_diversity/shannon/female_shannon_entropy.csv').iloc[n:150]
donorA_alpha_df = pd.read_csv(wd + 'alpha_diversity/shannon/donorA_shannon_entropy.csv').iloc[n:150]
donorB_alpha_df = pd.read_csv(wd + 'alpha_diversity/shannon/donorB_shannon_entropy.csv').iloc[n:150]

datasets = [male_alpha_df, female_alpha_df, donorA_alpha_df, donorB_alpha_df]#.iloc[:150]]
subjects = ['Male', 'Female', 'DonorA', 'DonorB']
s_analysis = SeasonalityAnalysis(subjects, datasets)

# %%
flatness_scores = s_analysis.calculate_flatness_scores('shannon_entropy')
flatness_scores
# Out:
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonality_analysis.py:55: UserWarning: nperseg = 256 is greater than input length  = 150, using nperseg = 150
#   f, t, Sxx = signal.spectrogram(detrended_ts)  # get spectrogram
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonality_analysis.py:55: UserWarning: nperseg = 256 is greater than input length  = 150, using nperseg = 150
#   f, t, Sxx = signal.spectrogram(detrended_ts)  # get spectrogram
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonality_analysis.py:55: UserWarning: nperseg = 256 is greater than input length  = 150, using nperseg = 150
#   f, t, Sxx = signal.spectrogram(detrended_ts)  # get spectrogram
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonality_analysis.py:55: UserWarning: nperseg = 256 is greater than input length  = 150, using nperseg = 150
#   f, t, Sxx = signal.spectrogram(detrended_ts)  # get spectrogram
# ['Male: [0.04577017]',
#  'Female: [0.01838841]',
#  'DonorA: [0.04003065]',
#  'DonorB: [0.03753875]']

# %%
for dataset, subject in zip(s_analysis.datasets, s_analysis.subjects):
    s_analysis.plot_fft(dataset['shannon_entropy'], 5, subject, True)

# %%
reconstruction_scores = s_analysis.calculate_reconstruction_scores()
reconstruction_scores
# Out:
#    coeff  n_modes subject
# 0   0.56        1    Male
# 1   0.70        2    Male
# 2   0.74        3    Male
# 3   0.75        4    Male
# 4   0.78        5    Male
# 5   0.80        6    Male
# 6   0.82        7    Male
# 7   0.85        8    Male
# 8   0.89        9    Male
# 9   0.90       10    Male
# 0   0.41        1  Female
# 1   0.50        2  Female
# 2   0.56        3  Female
# 3   0.56        4  Female
# 4   0.58        5  Female
# 5   0.60        6  Female
# 6   0.60        7  Female
# 7   0.60        8  Female
# 8   0.61        9  Female
# 9   0.60       10  Female
# 0   0.48        1  DonorA
# 1   0.64        2  DonorA
# 2   0.69        3  DonorA
# 3   0.79        4  DonorA
# 4   0.78        5  DonorA
# 5   0.83        6  DonorA
# 6   0.85        7  DonorA
# 7   0.87        8  DonorA
# 8   0.88        9  DonorA
# 9   0.89       10  DonorA
# 0   0.46        1  DonorB
# 1   0.59        2  DonorB
# 2   0.68        3  DonorB
# 3   0.77        4  DonorB
# 4   0.80        5  DonorB
# 5   0.84        6  DonorB
# 6   0.85        7  DonorB
# 7   0.88        8  DonorB
# 8   0.88        9  DonorB
# 9   0.86       10  DonorB

# %%
cmap = {
    'Male': '#d36135',
    'Female': '#ffb400',
    'DonorA': '#227c9d',
    'DonorB': '#7fb069'
}

# %%
s_analysis.plot_n_modes_vs_coeff(reconstruction_scores, cmap)

# %% [markdown]
# # Faith's PD index

# %%
#faiths
wd =  './data/data_original/alpha_diversity/faiths_pd/'

male_alpha_df = pd.read_csv(wd + 'male_faiths_pd.csv', sep='\t').iloc[:150]
male_alpha_df.index.name = '#SampleID'
female_alpha_df = pd.read_csv(wd + 'female_faiths_pd.tsv', sep='\t', index_col = [0]).iloc[:150]
donorA_alpha_df = pd.read_csv(wd + 'donorA_faiths_pd.tsv', sep='\t', index_col = [0]).iloc[:150]
donorB_alpha_df = pd.read_csv(wd + 'donorB_faiths_pd.tsv', sep='\t', index_col = [0]).iloc[:150]

datasets = [male_alpha_df, female_alpha_df, donorA_alpha_df, donorB_alpha_df.iloc[:150]]
subjects = ['Male', 'Female', 'DonorA', 'DonorB']

# %%
f_analysis = SeasonalityAnalysis(subjects, datasets)

# %%
flatness_scores = f_analysis.calculate_flatness_scores('faith_pd')
flatness_scores
# Out:
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonality_analysis.py:55: UserWarning: nperseg = 256 is greater than input length  = 150, using nperseg = 150
#   f, t, Sxx = signal.spectrogram(detrended_ts)  # get spectrogram
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonality_analysis.py:55: UserWarning: nperseg = 256 is greater than input length  = 150, using nperseg = 150
#   f, t, Sxx = signal.spectrogram(detrended_ts)  # get spectrogram
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonality_analysis.py:55: UserWarning: nperseg = 256 is greater than input length  = 150, using nperseg = 150
#   f, t, Sxx = signal.spectrogram(detrended_ts)  # get spectrogram
# D:\AGH-Infa\Sano\dynamo_library\dynamo\seasonality_analysis.py:55: UserWarning: nperseg = 256 is greater than input length  = 150, using nperseg = 150
#   f, t, Sxx = signal.spectrogram(detrended_ts)  # get spectrogram
# ['Male: [0.04819733]',
#  'Female: [0.02359452]',
#  'DonorA: [0.14315978]',
#  'DonorB: [0.0257166]']

# %%
for dataset, subject in zip(f_analysis.datasets, f_analysis.subjects):
    f_analysis.plot_fft(dataset['faith_pd'], 5, subject, True)

# %%
reconstruction_scores = f_analysis.calculate_reconstruction_scores()
reconstruction_scores
# Out:
#    coeff  n_modes subject
# 0   0.49        1    Male
# 1   0.55        2    Male
# 2   0.62        3    Male
# 3   0.67        4    Male
# 4   0.71        5    Male
# 5   0.74        6    Male
# 6   0.78        7    Male
# 7   0.80        8    Male
# 8   0.81        9    Male
# 9   0.84       10    Male
# 0   0.51        1  Female
# 1   0.73        2  Female
# 2   0.75        3  Female
# 3   0.77        4  Female
# 4   0.78        5  Female
# 5   0.81        6  Female
# 6   0.80        7  Female
# 7   0.80        8  Female
# 8   0.81        9  Female
# 9   0.81       10  Female
# 0   0.52        1  DonorA
# 1   0.65        2  DonorA
# 2   0.76        3  DonorA
# 3   0.74        4  DonorA
# 4   0.80        5  DonorA
# 5   0.83        6  DonorA
# 6   0.87        7  DonorA
# 7   0.87        8  DonorA
# 8   0.86        9  DonorA
# 9   0.87       10  DonorA
# 0   0.54        1  DonorB
# 1   0.64        2  DonorB
# 2   0.69        3  DonorB
# 3   0.81        4  DonorB
# 4   0.83        5  DonorB
# 5   0.81        6  DonorB
# 6   0.82        7  DonorB
# 7   0.82        8  DonorB
# 8   0.83        9  DonorB
# 9   0.82       10  DonorB

# %%
cmap = {
    'Male': '#d36135',
    'Female': '#ffb400',
    'DonorA': '#227c9d',
    'DonorB': '#7fb069'
}

# %%
f_analysis.plot_n_modes_vs_coeff(reconstruction_scores, cmap)
